# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import roc_auc_score, f1_score
from sklearn.preprocessing import MinMaxScaler, Normalizer, LabelEncoder

# %matplotlib inline

# %%
train = pd.read_csv("../data/train.csv")
test = pd.read_csv("../data/test.csv")
test["is_promoted"] = np.nan
print train.shape, test.shape
# Out:
# (54808, 14) (23490, 14)

# %% [markdown]
# # Simple LGBM Model

# %%
train_id = train[["employee_id"]]
test_id = test[["employee_id"]]
target = train.is_promoted

train = train.drop(["employee_id","is_promoted"], axis=1)
test = test.drop(["employee_id","is_promoted"], axis=1)

data = pd.concat([train, test], axis=0).reset_index(drop=True)
data["previous_year_rating"] = data["previous_year_rating"].fillna(0)
data["education"] = data["education"].fillna("NoData")

# Feature Engineering Start
data["department_size"] = data["department"].map(data.groupby("department").size())

data["department_average_training_scores"] = data["department"].map(data.groupby("department")["avg_training_score"].apply(lambda x: np.array(x)))
data["percentile_average_training_score_in_department"] = data.apply(lambda x: ((x["department_average_training_scores"] < x["avg_training_score"]).astype(int).sum() + ((x["department_average_training_scores"] == x["avg_training_score"]).astype(int).sum()*0.5))/len(x["department_average_training_scores"]), axis=1)
data["t_average_training_score_in_department"] = data.apply(lambda x: (np.mean(x["department_average_training_scores"]) - x["avg_training_score"])/(np.std(x["department_average_training_scores"])/np.sqrt(len(x["department_average_training_scores"]))), axis=1)
data = data.drop(["department_average_training_scores"], axis=1)

data["kpi_positive_department_average_training_scores"] = data["department"].map(data.loc[data["KPIs_met >80%"] ==1].groupby("department")["avg_training_score"].apply(lambda x: np.array(x)))
data["percentile_kpi_positive_average_training_score_in_department"] = data.apply(lambda x: ((x["kpi_positive_department_average_training_scores"] < x["avg_training_score"]).astype(int).sum() + ((x["kpi_positive_department_average_training_scores"] == x["avg_training_score"]).astype(int).sum()*0.5))/len(x["kpi_positive_department_average_training_scores"]), axis=1)
data = data.drop(["kpi_positive_department_average_training_scores"], axis=1)

# Feature Engineering End


data = pd.get_dummies(data, columns = data.select_dtypes(include='object').columns)

train = data[:train.shape[0]]
test = data[train.shape[0]:]

# %%
def f1_score_calculator(y_true, y_pred):
    bst = 0
    split_by = 0.0
    for i in range(100):
        fs = f1_score(y_true, (y_pred>i/100.0).astype(int))
        if fs > bst:
            bst , split_by = fs, i/100.0
        else:
            pass
    return split_by, bst

# %%
import lightgbm as lgb
def model_tree(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id):
    dtrain = lgb.Dataset(x_train, label=y_train)
    dval = lgb.Dataset(x_test, label=y_test)
    params = {
        'num_leaves': 32, 
        'reg_alpha': 0.04, 
        'n_jobs': -1, 
        'colsample_bytree': 0.9497036, 
        'silent': -1, 
        'subsample_for_bin': 200000, 
        'subsample_freq': 1, 
        'learning_rate': 0.02, 
        'boosting_type': 'gbdt', 
        'nthread': 8, 
        'min_child_weight': 40, 
        'min_split_gain': 0.0222415, 
        'n_estimators': 10000, 
        'subsample': 0.8715623, 
        'reg_lambda': 0.073, 
        'objective': "binary",
        'verbose': -1, 
        'min_child_samples': 20, 
        'max_depth': 4, 
        'class_weight': None,
        "nthread":8,
        "bagging_seed" : 42,
        "seed":98,
        "metric":"auc"
    }
    model = lgb.train(params, dtrain, num_boost_round=5000,valid_sets=[dtrain, dval], early_stopping_rounds=200, verbose_eval=100)
    meta_train[test_index] = model.predict(x_test, num_iteration=model.best_iteration or 5000)
    split, bst = f1_score_calculator(y_test, meta_train[test_index])
    
    meta_train[test_index] = (meta_train[test_index] > split).astype(int)
    meta_test.append((model.predict(test, num_iteration=model.best_iteration or 5000) > split).astype(int))
    
    print "Fold {} best Split {} and best Score {}".format(fold_id,split, bst)
        
    # Calculate Feature Importance
    global feature_importance
    gain = model.feature_importance('gain')
    fold_feature_importance = pd.DataFrame({'feature':model.feature_name(), 'split':model.feature_importance('split'), 'gain':100 * gain / gain.sum()})
    feature_importance = feature_importance.append(fold_feature_importance, ignore_index=True)

# %%
meta_train = np.zeros(train.shape[0])
meta_test = []
feature_importance = pd.DataFrame()

kf = StratifiedKFold(n_splits= 50, shuffle=True, random_state=1343)
for fold_id, (train_index, test_index) in enumerate(kf.split(train, target)):
    x_train, x_test = train.iloc[train_index], train.iloc[test_index]
    y_train, y_test = target[train_index], target[test_index]

    model_tree(x_train, x_test, y_train, y_test, test, meta_train, meta_test,train_index, test_index,fold_id)
print "Overall Score: {}".format(f1_score(target, meta_train))

train_id["is_promoted"] = meta_train
test_id["is_promoted"] = (np.array(meta_test).T.mean(axis=1) > 0.5).astype(int)
# Out:
# /anaconda2/lib/python2.7/site-packages/lightgbm/engine.py:99: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /anaconda2/lib/python2.7/site-packages/lightgbm/basic.py:657: UserWarning: silent keyword has been found in `params` and will be ignored. Please use silent argument of the Dataset constructor to pass this parameter.
#   'Please use {0} argument of the Dataset constructor to pass this parameter.'.format(key))
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903601	valid_1's auc: 0.902781
# [200]	training's auc: 0.91067	valid_1's auc: 0.905894
# [300]	training's auc: 0.913379	valid_1's auc: 0.905958
# [400]	training's auc: 0.916098	valid_1's auc: 0.905406
# Early stopping, best iteration is:
# [248]	training's auc: 0.912175	valid_1's auc: 0.907305
# Fold 0 best Split 0.23 and best Score 0.544217687075
# /anaconda2/lib/python2.7/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903741	valid_1's auc: 0.91099
# [200]	training's auc: 0.910317	valid_1's auc: 0.917513
# [300]	training's auc: 0.913091	valid_1's auc: 0.920064
# [400]	training's auc: 0.915652	valid_1's auc: 0.92077
# [500]	training's auc: 0.917422	valid_1's auc: 0.921406
# [600]	training's auc: 0.918922	valid_1's auc: 0.922297
# [700]	training's auc: 0.920219	valid_1's auc: 0.922329
# [800]	training's auc: 0.921254	valid_1's auc: 0.921671
# Early stopping, best iteration is:
# [633]	training's auc: 0.919336	valid_1's auc: 0.922392
# Fold 1 best Split 0.27 and best Score 0.601307189542
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.902928	valid_1's auc: 0.913716
# [200]	training's auc: 0.91025	valid_1's auc: 0.923464
# [300]	training's auc: 0.912803	valid_1's auc: 0.923077
# [400]	training's auc: 0.915573	valid_1's auc: 0.925983
# [500]	training's auc: 0.917336	valid_1's auc: 0.926815
# [600]	training's auc: 0.918808	valid_1's auc: 0.927346
# [700]	training's auc: 0.920062	valid_1's auc: 0.927727
# [800]	training's auc: 0.921187	valid_1's auc: 0.927335
# Early stopping, best iteration is:
# [653]	training's auc: 0.919465	valid_1's auc: 0.927844
# Fold 2 best Split 0.23 and best Score 0.573170731707
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904169	valid_1's auc: 0.891215
# [200]	training's auc: 0.910704	valid_1's auc: 0.891878
# [300]	training's auc: 0.913461	valid_1's auc: 0.897876
# [400]	training's auc: 0.915932	valid_1's auc: 0.898941
# [500]	training's auc: 0.917782	valid_1's auc: 0.899207
# [600]	training's auc: 0.91926	valid_1's auc: 0.899695
# [700]	training's auc: 0.920566	valid_1's auc: 0.900575
# [800]	training's auc: 0.921712	valid_1's auc: 0.901169
# [900]	training's auc: 0.922546	valid_1's auc: 0.900819
# Early stopping, best iteration is:
# [783]	training's auc: 0.921507	valid_1's auc: 0.901169
# Fold 3 best Split 0.23 and best Score 0.5
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903646	valid_1's auc: 0.89533
# [200]	training's auc: 0.910546	valid_1's auc: 0.902442
# [300]	training's auc: 0.913593	valid_1's auc: 0.904653
# [400]	training's auc: 0.916132	valid_1's auc: 0.907013
# [500]	training's auc: 0.917781	valid_1's auc: 0.907946
# [600]	training's auc: 0.919265	valid_1's auc: 0.90923
# [700]	training's auc: 0.920682	valid_1's auc: 0.910004
# [800]	training's auc: 0.921625	valid_1's auc: 0.910725
# [900]	training's auc: 0.922597	valid_1's auc: 0.910609
# [1000]	training's auc: 0.923376	valid_1's auc: 0.910831
# [1100]	training's auc: 0.924137	valid_1's auc: 0.911001
# [1200]	training's auc: 0.924862	valid_1's auc: 0.910937
# [1300]	training's auc: 0.925544	valid_1's auc: 0.911075
# [1400]	training's auc: 0.92636	valid_1's auc: 0.911309
# [1500]	training's auc: 0.926946	valid_1's auc: 0.911234
# [1600]	training's auc: 0.927613	valid_1's auc: 0.91134
# [1700]	training's auc: 0.928168	valid_1's auc: 0.911627
# [1800]	training's auc: 0.92868	valid_1's auc: 0.912083
# [1900]	training's auc: 0.92912	valid_1's auc: 0.911987
# [2000]	training's auc: 0.929665	valid_1's auc: 0.911903
# [2100]	training's auc: 0.930144	valid_1's auc: 0.912178
# [2200]	training's auc: 0.930633	valid_1's auc: 0.912274
# [2300]	training's auc: 0.931156	valid_1's auc: 0.912571
# [2400]	training's auc: 0.931615	valid_1's auc: 0.912709
# [2500]	training's auc: 0.932089	valid_1's auc: 0.912783
# [2600]	training's auc: 0.93254	valid_1's auc: 0.912815
# [2700]	training's auc: 0.932937	valid_1's auc: 0.912847
# [2800]	training's auc: 0.93328	valid_1's auc: 0.912963
# [2900]	training's auc: 0.933706	valid_1's auc: 0.91256
# Early stopping, best iteration is:
# [2757]	training's auc: 0.933116	valid_1's auc: 0.913059
# Fold 4 best Split 0.24 and best Score 0.511627906977
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90404	valid_1's auc: 0.90783
# [200]	training's auc: 0.910292	valid_1's auc: 0.91325
# [300]	training's auc: 0.913193	valid_1's auc: 0.917556
# [400]	training's auc: 0.915691	valid_1's auc: 0.920526
# [500]	training's auc: 0.917523	valid_1's auc: 0.923379
# [600]	training's auc: 0.918993	valid_1's auc: 0.924736
# [700]	training's auc: 0.920136	valid_1's auc: 0.925797
# [800]	training's auc: 0.921331	valid_1's auc: 0.927558
# [900]	training's auc: 0.922368	valid_1's auc: 0.928693
# [1000]	training's auc: 0.923166	valid_1's auc: 0.929212
# [1100]	training's auc: 0.924049	valid_1's auc: 0.930146
# [1200]	training's auc: 0.924727	valid_1's auc: 0.93022
# [1300]	training's auc: 0.9254	valid_1's auc: 0.930475
# [1400]	training's auc: 0.926143	valid_1's auc: 0.930485
# [1500]	training's auc: 0.926807	valid_1's auc: 0.93057
# [1600]	training's auc: 0.927374	valid_1's auc: 0.930634
# Early stopping, best iteration is:
# [1451]	training's auc: 0.926492	valid_1's auc: 0.930772
# Fold 5 best Split 0.23 and best Score 0.613636363636
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903136	valid_1's auc: 0.918081
# [200]	training's auc: 0.910415	valid_1's auc: 0.922891
# [300]	training's auc: 0.913001	valid_1's auc: 0.922546
# Early stopping, best iteration is:
# [184]	training's auc: 0.90922	valid_1's auc: 0.923448
# Fold 6 best Split 0.19 and best Score 0.552147239264
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904499	valid_1's auc: 0.889396
# [200]	training's auc: 0.910755	valid_1's auc: 0.889735
# Early stopping, best iteration is:
# [20]	training's auc: 0.894368	valid_1's auc: 0.89165
# Fold 7 best Split 0.41 and best Score 0.530303030303
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904438	valid_1's auc: 0.878773
# [200]	training's auc: 0.911003	valid_1's auc: 0.882337
# [300]	training's auc: 0.913882	valid_1's auc: 0.884119
# [400]	training's auc: 0.916392	valid_1's auc: 0.885079
# [500]	training's auc: 0.918173	valid_1's auc: 0.884379
# Early stopping, best iteration is:
# [380]	training's auc: 0.915926	valid_1's auc: 0.885498
# Fold 8 best Split 0.52 and best Score 0.492063492063
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903274	valid_1's auc: 0.912104
# [200]	training's auc: 0.910249	valid_1's auc: 0.916782
# [300]	training's auc: 0.913115	valid_1's auc: 0.918123
# [400]	training's auc: 0.9157	valid_1's auc: 0.919709
# [500]	training's auc: 0.917583	valid_1's auc: 0.920451
# [600]	training's auc: 0.919155	valid_1's auc: 0.920907
# [700]	training's auc: 0.920483	valid_1's auc: 0.92043
# [800]	training's auc: 0.921457	valid_1's auc: 0.920748
# Early stopping, best iteration is:
# [601]	training's auc: 0.919157	valid_1's auc: 0.920971
# Fold 9 best Split 0.29 and best Score 0.567375886525
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903264	valid_1's auc: 0.924068
# [200]	training's auc: 0.910357	valid_1's auc: 0.929239
# [300]	training's auc: 0.912783	valid_1's auc: 0.93144
# [400]	training's auc: 0.915238	valid_1's auc: 0.930315
# Early stopping, best iteration is:
# [258]	training's auc: 0.911676	valid_1's auc: 0.931795
# Fold 10 best Split 0.17 and best Score 0.584158415842
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903722	valid_1's auc: 0.903481
# [200]	training's auc: 0.910706	valid_1's auc: 0.912709
# [300]	training's auc: 0.913118	valid_1's auc: 0.9165
# [400]	training's auc: 0.915486	valid_1's auc: 0.915344
# [500]	training's auc: 0.917469	valid_1's auc: 0.914894
# Early stopping, best iteration is:
# [310]	training's auc: 0.913538	valid_1's auc: 0.916882
# Fold 11 best Split 0.24 and best Score 0.537931034483
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903446	valid_1's auc: 0.898687
# [200]	training's auc: 0.910728	valid_1's auc: 0.906621
# [300]	training's auc: 0.913323	valid_1's auc: 0.910571
# [400]	training's auc: 0.916351	valid_1's auc: 0.912624
# [500]	training's auc: 0.917999	valid_1's auc: 0.911648
# Early stopping, best iteration is:
# [380]	training's auc: 0.91583	valid_1's auc: 0.912868
# Fold 12 best Split 0.35 and best Score 0.533333333333
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903207	valid_1's auc: 0.928316
# [200]	training's auc: 0.910154	valid_1's auc: 0.933704
# [300]	training's auc: 0.912936	valid_1's auc: 0.933831
# Early stopping, best iteration is:
# [183]	training's auc: 0.909262	valid_1's auc: 0.934563
# Fold 13 best Split 0.26 and best Score 0.597222222222
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903806	valid_1's auc: 0.89489
# [200]	training's auc: 0.91055	valid_1's auc: 0.901529
# [300]	training's auc: 0.91315	valid_1's auc: 0.904558
# [400]	training's auc: 0.915646	valid_1's auc: 0.905512
# [500]	training's auc: 0.917422	valid_1's auc: 0.906016
# [600]	training's auc: 0.919023	valid_1's auc: 0.90679
# [700]	training's auc: 0.920522	valid_1's auc: 0.907077
# [800]	training's auc: 0.921584	valid_1's auc: 0.90748
# [900]	training's auc: 0.922552	valid_1's auc: 0.908636
# [1000]	training's auc: 0.923379	valid_1's auc: 0.909378
# [1100]	training's auc: 0.924179	valid_1's auc: 0.909654
# [1200]	training's auc: 0.924958	valid_1's auc: 0.909919
# [1300]	training's auc: 0.925676	valid_1's auc: 0.91045
# [1400]	training's auc: 0.926424	valid_1's auc: 0.910725
# [1500]	training's auc: 0.927009	valid_1's auc: 0.910906
# [1600]	training's auc: 0.927801	valid_1's auc: 0.911393
# [1700]	training's auc: 0.928357	valid_1's auc: 0.911468
# [1800]	training's auc: 0.928924	valid_1's auc: 0.91185
# [1900]	training's auc: 0.929408	valid_1's auc: 0.911903
# [2000]	training's auc: 0.929895	valid_1's auc: 0.912125
# [2100]	training's auc: 0.930336	valid_1's auc: 0.912316
# [2200]	training's auc: 0.930808	valid_1's auc: 0.91239
# [2300]	training's auc: 0.931244	valid_1's auc: 0.912274
# Early stopping, best iteration is:
# [2171]	training's auc: 0.930642	valid_1's auc: 0.912613
# Fold 14 best Split 0.28 and best Score 0.516556291391
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903588	valid_1's auc: 0.904033
# [200]	training's auc: 0.910684	valid_1's auc: 0.908519
# [300]	training's auc: 0.913544	valid_1's auc: 0.906695
# Early stopping, best iteration is:
# [151]	training's auc: 0.907642	valid_1's auc: 0.908874
# Fold 15 best Split 0.23 and best Score 0.521126760563
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903966	valid_1's auc: 0.897133
# [200]	training's auc: 0.910686	valid_1's auc: 0.897536
# [300]	training's auc: 0.913434	valid_1's auc: 0.900559
# [400]	training's auc: 0.916028	valid_1's auc: 0.904128
# [500]	training's auc: 0.917578	valid_1's auc: 0.905793
# [600]	training's auc: 0.91895	valid_1's auc: 0.906674
# [700]	training's auc: 0.920313	valid_1's auc: 0.908021
# [800]	training's auc: 0.921364	valid_1's auc: 0.908859
# [900]	training's auc: 0.922315	valid_1's auc: 0.909569
# [1000]	training's auc: 0.923174	valid_1's auc: 0.910195
# [1100]	training's auc: 0.924117	valid_1's auc: 0.910683
# [1200]	training's auc: 0.924834	valid_1's auc: 0.910609
# [1300]	training's auc: 0.925538	valid_1's auc: 0.911075
# [1400]	training's auc: 0.926237	valid_1's auc: 0.911351
# [1500]	training's auc: 0.926948	valid_1's auc: 0.911828
# [1600]	training's auc: 0.927545	valid_1's auc: 0.911945
# [1700]	training's auc: 0.928162	valid_1's auc: 0.911956
# [1800]	training's auc: 0.928687	valid_1's auc: 0.91239
# [1900]	training's auc: 0.929231	valid_1's auc: 0.91255
# [2000]	training's auc: 0.929724	valid_1's auc: 0.912231
# Early stopping, best iteration is:
# [1889]	training's auc: 0.92918	valid_1's auc: 0.912581
# Fold 16 best Split 0.21 and best Score 0.489583333333
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90377	valid_1's auc: 0.885874
# [200]	training's auc: 0.91061	valid_1's auc: 0.897393
# [300]	training's auc: 0.913129	valid_1's auc: 0.900776
# [400]	training's auc: 0.915801	valid_1's auc: 0.903873
# [500]	training's auc: 0.917566	valid_1's auc: 0.904266
# [600]	training's auc: 0.918974	valid_1's auc: 0.905592
# [700]	training's auc: 0.920493	valid_1's auc: 0.906854
# [800]	training's auc: 0.921627	valid_1's auc: 0.906748
# [900]	training's auc: 0.922693	valid_1's auc: 0.907013
# [1000]	training's auc: 0.923569	valid_1's auc: 0.90714
# [1100]	training's auc: 0.924422	valid_1's auc: 0.907649
# [1200]	training's auc: 0.925123	valid_1's auc: 0.908042
# [1300]	training's auc: 0.925901	valid_1's auc: 0.908572
# [1400]	training's auc: 0.926516	valid_1's auc: 0.90871
# [1500]	training's auc: 0.927111	valid_1's auc: 0.908933
# Early stopping, best iteration is:
# [1345]	training's auc: 0.926239	valid_1's auc: 0.909039
# Fold 17 best Split 0.24 and best Score 0.531791907514
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90451	valid_1's auc: 0.892945
# [200]	training's auc: 0.91081	valid_1's auc: 0.902674
# [300]	training's auc: 0.91333	valid_1's auc: 0.901403
# [400]	training's auc: 0.915952	valid_1's auc: 0.904244
# [500]	training's auc: 0.917525	valid_1's auc: 0.905627
# [600]	training's auc: 0.919077	valid_1's auc: 0.906067
# [700]	training's auc: 0.920415	valid_1's auc: 0.905713
# [800]	training's auc: 0.921582	valid_1's auc: 0.90597
# [900]	training's auc: 0.922663	valid_1's auc: 0.906153
# [1000]	training's auc: 0.923489	valid_1's auc: 0.905842
# Early stopping, best iteration is:
# [847]	training's auc: 0.922072	valid_1's auc: 0.906613
# Fold 18 best Split 0.25 and best Score 0.535031847134
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903586	valid_1's auc: 0.909915
# [200]	training's auc: 0.910361	valid_1's auc: 0.908956
# [300]	training's auc: 0.913198	valid_1's auc: 0.910446
# Early stopping, best iteration is:
# [125]	training's auc: 0.905759	valid_1's auc: 0.91154
# Fold 19 best Split 0.2 and best Score 0.52380952381
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903623	valid_1's auc: 0.895464
# [200]	training's auc: 0.910241	valid_1's auc: 0.902818
# [300]	training's auc: 0.913478	valid_1's auc: 0.904443
# [400]	training's auc: 0.915875	valid_1's auc: 0.906067
# [500]	training's auc: 0.917668	valid_1's auc: 0.906153
# [600]	training's auc: 0.919294	valid_1's auc: 0.906035
# Early stopping, best iteration is:
# [457]	training's auc: 0.916852	valid_1's auc: 0.906378
# Fold 20 best Split 0.18 and best Score 0.483720930233
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903662	valid_1's auc: 0.904266
# [200]	training's auc: 0.910663	valid_1's auc: 0.911915
# [300]	training's auc: 0.913226	valid_1's auc: 0.91154
# [400]	training's auc: 0.915647	valid_1's auc: 0.908634
# Early stopping, best iteration is:
# [218]	training's auc: 0.911483	valid_1's auc: 0.912762
# Fold 21 best Split 0.24 and best Score 0.552631578947
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904259	valid_1's auc: 0.885526
# [200]	training's auc: 0.910795	valid_1's auc: 0.892709
# [300]	training's auc: 0.913317	valid_1's auc: 0.89593
# [400]	training's auc: 0.915949	valid_1's auc: 0.899366
# [500]	training's auc: 0.91765	valid_1's auc: 0.90031
# [600]	training's auc: 0.91913	valid_1's auc: 0.901028
# [700]	training's auc: 0.920481	valid_1's auc: 0.901543
# [800]	training's auc: 0.92154	valid_1's auc: 0.900846
# Early stopping, best iteration is:
# [696]	training's auc: 0.920404	valid_1's auc: 0.901564
# Fold 22 best Split 0.21 and best Score 0.485549132948
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90362	valid_1's auc: 0.913298
# [200]	training's auc: 0.910746	valid_1's auc: 0.915302
# [300]	training's auc: 0.91325	valid_1's auc: 0.91147
# Early stopping, best iteration is:
# [143]	training's auc: 0.906664	valid_1's auc: 0.918395
# Fold 23 best Split 0.26 and best Score 0.529411764706
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903349	valid_1's auc: 0.902079
# [200]	training's auc: 0.910552	valid_1's auc: 0.912499
# [300]	training's auc: 0.913311	valid_1's auc: 0.915769
# [400]	training's auc: 0.915954	valid_1's auc: 0.915897
# [500]	training's auc: 0.917551	valid_1's auc: 0.915329
# Early stopping, best iteration is:
# [374]	training's auc: 0.915408	valid_1's auc: 0.91698
# Fold 24 best Split 0.42 and best Score 0.534351145038
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903419	valid_1's auc: 0.90292
# [200]	training's auc: 0.910404	valid_1's auc: 0.91207
# [300]	training's auc: 0.913212	valid_1's auc: 0.918251
# [400]	training's auc: 0.915556	valid_1's auc: 0.923509
# [500]	training's auc: 0.917209	valid_1's auc: 0.924817
# [600]	training's auc: 0.918726	valid_1's auc: 0.925546
# [700]	training's auc: 0.920075	valid_1's auc: 0.925857
# [800]	training's auc: 0.921168	valid_1's auc: 0.926157
# [900]	training's auc: 0.922237	valid_1's auc: 0.925953
# Early stopping, best iteration is:
# [729]	training's auc: 0.920332	valid_1's auc: 0.926414
# Fold 25 best Split 0.24 and best Score 0.625
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904001	valid_1's auc: 0.899709
# [200]	training's auc: 0.910408	valid_1's auc: 0.901773
# [300]	training's auc: 0.913346	valid_1's auc: 0.904276
# [400]	training's auc: 0.915847	valid_1's auc: 0.905756
# [500]	training's auc: 0.917663	valid_1's auc: 0.907214
# [600]	training's auc: 0.91908	valid_1's auc: 0.90835
# [700]	training's auc: 0.920336	valid_1's auc: 0.910055
# [800]	training's auc: 0.921397	valid_1's auc: 0.910484
# [900]	training's auc: 0.922442	valid_1's auc: 0.91147
# [1000]	training's auc: 0.923319	valid_1's auc: 0.912295
# [1100]	training's auc: 0.924188	valid_1's auc: 0.912692
# [1200]	training's auc: 0.925007	valid_1's auc: 0.912531
# [1300]	training's auc: 0.925608	valid_1's auc: 0.913174
# [1400]	training's auc: 0.926223	valid_1's auc: 0.912799
# [1500]	training's auc: 0.926902	valid_1's auc: 0.913325
# [1600]	training's auc: 0.927471	valid_1's auc: 0.913796
# [1700]	training's auc: 0.927976	valid_1's auc: 0.913582
# Early stopping, best iteration is:
# [1571]	training's auc: 0.92732	valid_1's auc: 0.914032
# Fold 26 best Split 0.25 and best Score 0.538461538462
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903835	valid_1's auc: 0.895298
# [200]	training's auc: 0.910913	valid_1's auc: 0.900337
# [300]	training's auc: 0.913567	valid_1's auc: 0.902347
# [400]	training's auc: 0.916208	valid_1's auc: 0.906737
# [500]	training's auc: 0.917703	valid_1's auc: 0.908179
# [600]	training's auc: 0.919389	valid_1's auc: 0.908575
# [700]	training's auc: 0.920434	valid_1's auc: 0.909058
# [800]	training's auc: 0.92151	valid_1's auc: 0.908661
# Early stopping, best iteration is:
# [662]	training's auc: 0.919966	valid_1's auc: 0.909122
# Fold 27 best Split 0.26 and best Score 0.559440559441
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903935	valid_1's auc: 0.880445
# [200]	training's auc: 0.91058	valid_1's auc: 0.888394
# [300]	training's auc: 0.913335	valid_1's auc: 0.889948
# [400]	training's auc: 0.91567	valid_1's auc: 0.891937
# [500]	training's auc: 0.917498	valid_1's auc: 0.894499
# [600]	training's auc: 0.919116	valid_1's auc: 0.894816
# [700]	training's auc: 0.920452	valid_1's auc: 0.895255
# [800]	training's auc: 0.921519	valid_1's auc: 0.894735
# [900]	training's auc: 0.922547	valid_1's auc: 0.895475
# [1000]	training's auc: 0.923396	valid_1's auc: 0.895989
# [1100]	training's auc: 0.924179	valid_1's auc: 0.896547
# [1200]	training's auc: 0.925003	valid_1's auc: 0.897748
# [1300]	training's auc: 0.925685	valid_1's auc: 0.897887
# [1400]	training's auc: 0.926381	valid_1's auc: 0.898788
# [1500]	training's auc: 0.92704	valid_1's auc: 0.899077
# [1600]	training's auc: 0.927633	valid_1's auc: 0.898745
# Early stopping, best iteration is:
# [1436]	training's auc: 0.926608	valid_1's auc: 0.899077
# Fold 28 best Split 0.6 and best Score 0.503937007874
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903583	valid_1's auc: 0.892848
# [200]	training's auc: 0.910602	valid_1's auc: 0.905606
# [300]	training's auc: 0.9133	valid_1's auc: 0.912306
# [400]	training's auc: 0.91577	valid_1's auc: 0.916433
# [500]	training's auc: 0.917411	valid_1's auc: 0.918942
# [600]	training's auc: 0.918732	valid_1's auc: 0.920775
# [700]	training's auc: 0.920229	valid_1's auc: 0.920797
# [800]	training's auc: 0.921229	valid_1's auc: 0.921365
# [900]	training's auc: 0.922242	valid_1's auc: 0.921483
# [1000]	training's auc: 0.923148	valid_1's auc: 0.921301
# Early stopping, best iteration is:
# [881]	training's auc: 0.922095	valid_1's auc: 0.921547
# Fold 29 best Split 0.25 and best Score 0.576923076923
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90359	valid_1's auc: 0.9114
# [200]	training's auc: 0.910367	valid_1's auc: 0.912858
# [300]	training's auc: 0.913124	valid_1's auc: 0.913298
# Early stopping, best iteration is:
# [125]	training's auc: 0.906027	valid_1's auc: 0.914852
# Fold 30 best Split 0.2 and best Score 0.521212121212
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90335	valid_1's auc: 0.909647
# [200]	training's auc: 0.910698	valid_1's auc: 0.911411
# [300]	training's auc: 0.913297	valid_1's auc: 0.91117
# [400]	training's auc: 0.91582	valid_1's auc: 0.911502
# Early stopping, best iteration is:
# [241]	training's auc: 0.912093	valid_1's auc: 0.913067
# Fold 31 best Split 0.55 and best Score 0.52380952381
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904151	valid_1's auc: 0.884025
# [200]	training's auc: 0.911099	valid_1's auc: 0.890115
# [300]	training's auc: 0.913611	valid_1's auc: 0.893744
# [400]	training's auc: 0.916234	valid_1's auc: 0.895839
# [500]	training's auc: 0.917917	valid_1's auc: 0.896718
# [600]	training's auc: 0.919393	valid_1's auc: 0.896472
# [700]	training's auc: 0.920667	valid_1's auc: 0.895829
# Early stopping, best iteration is:
# [508]	training's auc: 0.918026	valid_1's auc: 0.896869
# Fold 32 best Split 0.27 and best Score 0.492753623188
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90392	valid_1's auc: 0.89801
# [200]	training's auc: 0.910321	valid_1's auc: 0.908436
# [300]	training's auc: 0.913182	valid_1's auc: 0.911025
# [400]	training's auc: 0.915883	valid_1's auc: 0.911749
# [500]	training's auc: 0.917555	valid_1's auc: 0.911834
# [600]	training's auc: 0.919015	valid_1's auc: 0.911331
# [700]	training's auc: 0.920275	valid_1's auc: 0.911792
# Early stopping, best iteration is:
# [542]	training's auc: 0.918101	valid_1's auc: 0.912102
# Fold 33 best Split 0.33 and best Score 0.591549295775
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903154	valid_1's auc: 0.905279
# [200]	training's auc: 0.91025	valid_1's auc: 0.914622
# [300]	training's auc: 0.913162	valid_1's auc: 0.917602
# [400]	training's auc: 0.915866	valid_1's auc: 0.9198
# [500]	training's auc: 0.917087	valid_1's auc: 0.92069
# [600]	training's auc: 0.918744	valid_1's auc: 0.921322
# [700]	training's auc: 0.920007	valid_1's auc: 0.921451
# [800]	training's auc: 0.921174	valid_1's auc: 0.921258
# Early stopping, best iteration is:
# [694]	training's auc: 0.919928	valid_1's auc: 0.921569
# Fold 34 best Split 0.3 and best Score 0.571428571429
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90402	valid_1's auc: 0.904212
# [200]	training's auc: 0.910746	valid_1's auc: 0.910784
# [300]	training's auc: 0.913429	valid_1's auc: 0.912853
# [400]	training's auc: 0.915941	valid_1's auc: 0.914852
# [500]	training's auc: 0.917649	valid_1's auc: 0.917355
# [600]	training's auc: 0.919163	valid_1's auc: 0.91936
# [700]	training's auc: 0.920348	valid_1's auc: 0.920186
# [800]	training's auc: 0.921483	valid_1's auc: 0.921097
# [900]	training's auc: 0.922514	valid_1's auc: 0.922019
# [1000]	training's auc: 0.923375	valid_1's auc: 0.922362
# [1100]	training's auc: 0.924124	valid_1's auc: 0.922544
# [1200]	training's auc: 0.92478	valid_1's auc: 0.922898
# [1300]	training's auc: 0.925463	valid_1's auc: 0.922684
# Early stopping, best iteration is:
# [1180]	training's auc: 0.924631	valid_1's auc: 0.923134
# Fold 35 best Split 0.28 and best Score 0.6
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904449	valid_1's auc: 0.880488
# [200]	training's auc: 0.911149	valid_1's auc: 0.882996
# [300]	training's auc: 0.913727	valid_1's auc: 0.886025
# [400]	training's auc: 0.916213	valid_1's auc: 0.887761
# [500]	training's auc: 0.917814	valid_1's auc: 0.887258
# Early stopping, best iteration is:
# [386]	training's auc: 0.915871	valid_1's auc: 0.888255
# Fold 36 best Split 0.21 and best Score 0.479041916168
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904447	valid_1's auc: 0.892645
# [200]	training's auc: 0.910528	valid_1's auc: 0.899522
# [300]	training's auc: 0.913392	valid_1's auc: 0.904973
# [400]	training's auc: 0.91574	valid_1's auc: 0.908457
# [500]	training's auc: 0.917294	valid_1's auc: 0.911186
# [600]	training's auc: 0.918673	valid_1's auc: 0.912435
# [700]	training's auc: 0.920025	valid_1's auc: 0.912906
# [800]	training's auc: 0.921168	valid_1's auc: 0.913325
# [900]	training's auc: 0.922002	valid_1's auc: 0.913475
# [1000]	training's auc: 0.922943	valid_1's auc: 0.913174
# Early stopping, best iteration is:
# [826]	training's auc: 0.921354	valid_1's auc: 0.913657
# Fold 37 best Split 0.25 and best Score 0.506329113924
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903444	valid_1's auc: 0.908179
# [200]	training's auc: 0.910503	valid_1's auc: 0.916766
# [300]	training's auc: 0.913518	valid_1's auc: 0.917012
# [400]	training's auc: 0.915722	valid_1's auc: 0.916959
# [500]	training's auc: 0.917438	valid_1's auc: 0.917784
# [600]	training's auc: 0.919043	valid_1's auc: 0.917881
# [700]	training's auc: 0.920376	valid_1's auc: 0.917699
# [800]	training's auc: 0.921395	valid_1's auc: 0.917999
# Early stopping, best iteration is:
# [670]	training's auc: 0.920032	valid_1's auc: 0.918138
# Fold 38 best Split 0.21 and best Score 0.568181818182
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903468	valid_1's auc: 0.896938
# [200]	training's auc: 0.910615	valid_1's auc: 0.898026
# [300]	training's auc: 0.913661	valid_1's auc: 0.896429
# Early stopping, best iteration is:
# [146]	training's auc: 0.906836	valid_1's auc: 0.898927
# Fold 39 best Split 0.23 and best Score 0.548148148148
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903013	valid_1's auc: 0.917209
# [200]	training's auc: 0.91011	valid_1's auc: 0.926566
# [300]	training's auc: 0.913056	valid_1's auc: 0.927988
# [400]	training's auc: 0.915816	valid_1's auc: 0.928831
# [500]	training's auc: 0.91745	valid_1's auc: 0.928916
# [600]	training's auc: 0.918866	valid_1's auc: 0.929678
# [700]	training's auc: 0.92021	valid_1's auc: 0.929818
# [800]	training's auc: 0.921321	valid_1's auc: 0.930462
# [900]	training's auc: 0.922278	valid_1's auc: 0.930344
# [1000]	training's auc: 0.923115	valid_1's auc: 0.930494
# Early stopping, best iteration is:
# [844]	training's auc: 0.921793	valid_1's auc: 0.930698
# Fold 40 best Split 0.41 and best Score 0.625850340136
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903079	valid_1's auc: 0.922504
# [200]	training's auc: 0.91037	valid_1's auc: 0.9286
# [300]	training's auc: 0.913135	valid_1's auc: 0.928144
# [400]	training's auc: 0.915706	valid_1's auc: 0.929684
# [500]	training's auc: 0.917453	valid_1's auc: 0.930226
# [600]	training's auc: 0.918967	valid_1's auc: 0.931524
# [700]	training's auc: 0.920082	valid_1's auc: 0.931996
# [800]	training's auc: 0.921206	valid_1's auc: 0.932651
# [900]	training's auc: 0.922183	valid_1's auc: 0.933359
# [1000]	training's auc: 0.923106	valid_1's auc: 0.933627
# [1100]	training's auc: 0.923893	valid_1's auc: 0.933939
# [1200]	training's auc: 0.924656	valid_1's auc: 0.934142
# [1300]	training's auc: 0.925355	valid_1's auc: 0.934218
# [1400]	training's auc: 0.926098	valid_1's auc: 0.934228
# Early stopping, best iteration is:
# [1250]	training's auc: 0.924961	valid_1's auc: 0.934421
# Fold 41 best Split 0.41 and best Score 0.642857142857
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903255	valid_1's auc: 0.90256
# [200]	training's auc: 0.910372	valid_1's auc: 0.910807
# [300]	training's auc: 0.91287	valid_1's auc: 0.915594
# [400]	training's auc: 0.915443	valid_1's auc: 0.91884
# [500]	training's auc: 0.917341	valid_1's auc: 0.919977
# [600]	training's auc: 0.918802	valid_1's auc: 0.920267
# [700]	training's auc: 0.920106	valid_1's auc: 0.92104
# [800]	training's auc: 0.921248	valid_1's auc: 0.920997
# [900]	training's auc: 0.922263	valid_1's auc: 0.92105
# [1000]	training's auc: 0.923224	valid_1's auc: 0.920911
# Early stopping, best iteration is:
# [863]	training's auc: 0.921863	valid_1's auc: 0.921286
# Fold 42 best Split 0.28 and best Score 0.605263157895
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904711	valid_1's auc: 0.867357
# [200]	training's auc: 0.911304	valid_1's auc: 0.865119
# Early stopping, best iteration is:
# [87]	training's auc: 0.902603	valid_1's auc: 0.869133
# Fold 43 best Split 0.25 and best Score 0.467153284672
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903688	valid_1's auc: 0.905758
# [200]	training's auc: 0.910638	valid_1's auc: 0.910829
# [300]	training's auc: 0.913368	valid_1's auc: 0.911414
# [400]	training's auc: 0.916194	valid_1's auc: 0.912213
# [500]	training's auc: 0.917771	valid_1's auc: 0.911848
# Early stopping, best iteration is:
# [336]	training's auc: 0.914697	valid_1's auc: 0.912557
# Fold 44 best Split 0.28 and best Score 0.514285714286
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903371	valid_1's auc: 0.913399
# [200]	training's auc: 0.910718	valid_1's auc: 0.9195
# [300]	training's auc: 0.913219	valid_1's auc: 0.920959
# [400]	training's auc: 0.915934	valid_1's auc: 0.922295
# [500]	training's auc: 0.91772	valid_1's auc: 0.922252
# [600]	training's auc: 0.919065	valid_1's auc: 0.921415
# Early stopping, best iteration is:
# [438]	training's auc: 0.916528	valid_1's auc: 0.922757
# Fold 45 best Split 0.19 and best Score 0.54347826087
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.904604	valid_1's auc: 0.873076
# [200]	training's auc: 0.910899	valid_1's auc: 0.876747
# [300]	training's auc: 0.913861	valid_1's auc: 0.883969
# [400]	training's auc: 0.916539	valid_1's auc: 0.886142
# [500]	training's auc: 0.918326	valid_1's auc: 0.886474
# [600]	training's auc: 0.919972	valid_1's auc: 0.887419
# [700]	training's auc: 0.921368	valid_1's auc: 0.886936
# Early stopping, best iteration is:
# [594]	training's auc: 0.91988	valid_1's auc: 0.887633
# Fold 46 best Split 0.26 and best Score 0.503703703704
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903345	valid_1's auc: 0.906874
# [200]	training's auc: 0.910377	valid_1's auc: 0.911344
# [300]	training's auc: 0.913422	valid_1's auc: 0.9173
# [400]	training's auc: 0.915808	valid_1's auc: 0.919655
# [500]	training's auc: 0.917558	valid_1's auc: 0.922188
# [600]	training's auc: 0.918929	valid_1's auc: 0.923143
# [700]	training's auc: 0.9201	valid_1's auc: 0.923755
# [800]	training's auc: 0.921226	valid_1's auc: 0.924871
# [900]	training's auc: 0.922185	valid_1's auc: 0.925557
# [1000]	training's auc: 0.923127	valid_1's auc: 0.926051
# [1100]	training's auc: 0.923957	valid_1's auc: 0.926169
# Early stopping, best iteration is:
# [993]	training's auc: 0.923078	valid_1's auc: 0.926276
# Fold 47 best Split 0.21 and best Score 0.527472527473
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.903296	valid_1's auc: 0.904363
# [200]	training's auc: 0.910662	valid_1's auc: 0.914231
# [300]	training's auc: 0.912913	valid_1's auc: 0.916361
# [400]	training's auc: 0.915507	valid_1's auc: 0.918443
# [500]	training's auc: 0.917103	valid_1's auc: 0.91987
# [600]	training's auc: 0.918712	valid_1's auc: 0.92104
# [700]	training's auc: 0.92001	valid_1's auc: 0.92192
# [800]	training's auc: 0.9213	valid_1's auc: 0.92325
# [900]	training's auc: 0.922279	valid_1's auc: 0.923325
# [1000]	training's auc: 0.923132	valid_1's auc: 0.923261
# [1100]	training's auc: 0.923907	valid_1's auc: 0.923744
# [1200]	training's auc: 0.924549	valid_1's auc: 0.923905
# [1300]	training's auc: 0.925238	valid_1's auc: 0.924044
# [1400]	training's auc: 0.925903	valid_1's auc: 0.924023
# Early stopping, best iteration is:
# [1264]	training's auc: 0.925013	valid_1's auc: 0.92427
# Fold 48 best Split 0.18 and best Score 0.545454545455
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.90379	valid_1's auc: 0.906075
# [200]	training's auc: 0.910654	valid_1's auc: 0.910271
# [300]	training's auc: 0.913301	valid_1's auc: 0.913082
# [400]	training's auc: 0.91559	valid_1's auc: 0.912401
# [500]	training's auc: 0.917492	valid_1's auc: 0.912905
# [600]	training's auc: 0.91912	valid_1's auc: 0.913742
# [700]	training's auc: 0.920348	valid_1's auc: 0.914064
# [800]	training's auc: 0.921381	valid_1's auc: 0.913914
# Early stopping, best iteration is:
# [623]	training's auc: 0.919462	valid_1's auc: 0.914408
# Fold 49 best Split 0.28 and best Score 0.540145985401
# Overall Score: 0.543003851091

# %%
test_id.to_csv("csv/prediction4.csv", index = False)

# %%
test_id["is_promoted"].mean()
# Out:
# 0.04776500638569604

# %%
feature_importance.groupby("feature")["gain"].mean().sort_values().plot(kind = "barh", figsize = (22,22))
